# %%
import time

def countdown(t):
    while t:
        mins, secs = divmod(t, 60)
        print(f"{mins:02}:{secs:02} SEC", end="\r")
        time.sleep(1)
        t -= 1

    print("💥 Fire in the hole! 💥")

# Input time in seconds
seconds = int(input("⏰ Enter the countdown time in seconds: "))

# Function call
countdown(seconds)
# Out:
# ⏰ Enter the countdown time in seconds: 5
# 💥 Fire in the hole! 💥
