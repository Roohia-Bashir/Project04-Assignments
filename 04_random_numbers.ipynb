# %%
# prompt: Problem Statement
# Print 10 random numbers in the range 1 to 100.
# Here is an example run:
# 45 79 61 47 52 10 16 83 19 12
# Each time you run your program you should get different numbers
# 81 76 70 1 27 63 96 100 32 92
# Recall that the python random library has a function randint which returns an integer in the range set by the parameters (inclusive). For example this call would produce a random integer between 1 and 6, which could include 1 and could include 6:
# value = random.randint(1, 6)
# Starter Code
# import random
# N_NUMBERS: int = 10
# MIN_VALUE: int = 1
# MAX_VALUE: int = 100
# def main():
#     """
#     You should write your code here. Make sure to delete
#     the 'pass' line before starting to write your own code.
#     """
#     pass
# if __name__ == '__main__':
#     main()

import random

N_NUMBERS: int = 10
MIN_VALUE: int = 1
MAX_VALUE: int = 100

def main():
    """
    🎮 Guess the Secret Number Game! 🎮
    Try to guess a number between 1 and 100.
    But, beware! There are 10 chances to guess correctly! 🔮
    """
    print("🎉 Welcome to the 'Guess the Secret Number' Game! 🎉")
    print(f"🎯 Try to guess the secret number between {MIN_VALUE} and {MAX_VALUE} in 10 attempts! 🏆")

    secret_number = random.randint(MIN_VALUE, MAX_VALUE)
    attempts_left = N_NUMBERS

    while attempts_left > 0:
        print(f"💡 You have {attempts_left} attempts left! 💡")

        try:
            guess = int(input("🔍 Enter your guess: "))
        except ValueError:
            print("❌ Oops! Please enter a valid integer. ❌")
            continue

        if guess < secret_number:
            print("⬇️ Your guess is too low! Try again! ⬇️")
        elif guess > secret_number:
            print("⬆️ Your guess is too high! Try again! ⬆️")
        else:
            print(f"🎉🎯 Hooray! You guessed the number {secret_number}! 🎯🎉")
            break

        attempts_left -= 1

    if attempts_left == 0:
        print(f"😢 Sorry, you've run out of attempts! The correct number was {secret_number}. Better luck next time! 😢")

if __name__ == '__main__':
    main()
# Out:
# 🎉 Welcome to the 'Guess the Secret Number' Game! 🎉
# 🎯 Try to guess the secret number between 1 and 100 in 10 attempts! 🏆
# 💡 You have 10 attempts left! 💡
# 🔍 Enter your guess: 25
# ⬆️ Your guess is too high! Try again! ⬆️
# 💡 You have 9 attempts left! 💡
# 🔍 Enter your guess: 15
# ⬆️ Your guess is too high! Try again! ⬆️
# 💡 You have 8 attempts left! 💡
# 🔍 Enter your guess: 14
# ⬆️ Your guess is too high! Try again! ⬆️
# 💡 You have 7 attempts left! 💡
# 🔍 Enter your guess: 10
# ⬆️ Your guess is too high! Try again! ⬆️
# 💡 You have 6 attempts left! 💡
# 🔍 Enter your guess: 6
# ⬆️ Your guess is too high! Try again! ⬆️
# 💡 You have 5 attempts left! 💡
# 🔍 Enter your guess: 5
# ⬆️ Your guess is too high! Try again! ⬆️
# 💡 You have 4 attempts left! 💡
# 🔍 Enter your guess: 4
# 🎉🎯 Hooray! You guessed the number 4! 🎯🎉
